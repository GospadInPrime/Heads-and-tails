# %%
import matplotlib.pyplot as plt
from random import randint

# задаём параметры размера графика
f = plt.figure()
f.set_figwidth(17)

# список x будет хранить порядковые номера испытаний
x = []
# список y будет хранить доли выпавших орлов от текущего числа бросков монеты
y = []
# количество выпавших орлов
head_count = 0

# проводим 150 испытаний (от 1 до 150)
for i in range(1, 151):
    # добавляем текущий номер испытания в x
    x.append(i)
    # симулируем бросок монеты: 0 — решка, 1 — орёл
    coin = randint(0, 1)
    # если выпал орёл, то
    if coin == 1:
        # увеличиваем количество орлов на 1
        head_count += 1
    # подсчитываем текущую долю орлов
    head_part = head_count / i
    # добавляем её в список y
    y.append(head_part)
    # выводим долю орлов через каждые 5 шагов
    if i % 5 == 0:
        print(f'Шаг {i}, доля выпавших орлов на данный момент {head_part}')

# строим график
plt.plot(x, y, '-o')
plt.show()
# Out:
# Шаг 5, доля выпавших орлов на данный момент 0.4
# Шаг 10, доля выпавших орлов на данный момент 0.5
# Шаг 15, доля выпавших орлов на данный момент 0.4666666666666667
# Шаг 20, доля выпавших орлов на данный момент 0.4
# Шаг 25, доля выпавших орлов на данный момент 0.4
# Шаг 30, доля выпавших орлов на данный момент 0.43333333333333335
# Шаг 35, доля выпавших орлов на данный момент 0.45714285714285713
# Шаг 40, доля выпавших орлов на данный момент 0.475
# Шаг 45, доля выпавших орлов на данный момент 0.4666666666666667
# Шаг 50, доля выпавших орлов на данный момент 0.48
# Шаг 55, доля выпавших орлов на данный момент 0.4909090909090909
# Шаг 60, доля выпавших орлов на данный момент 0.5166666666666667
# Шаг 65, доля выпавших орлов на данный момент 0.5076923076923077
# Шаг 70, доля выпавших орлов на данный момент 0.5
# Шаг 75, доля выпавших орлов на данный момент 0.49333333333333335
# Шаг 80, доля выпавших орлов на данный момент 0.5
# Шаг 85, доля выпавших орлов на данный момент 0.5176470588235295
# Шаг 90, доля выпавших орлов на данный момент 0.5222222222222223
# Шаг 95, доля выпавших орлов на данный момент 0.5157894736842106
# Шаг 100, доля выпавших орлов на данный момент 0.52
# Шаг 105, доля выпавших орлов на данный момент 0.5238095238095238
# Шаг 110, доля выпавших орлов на данный момент 0.5181818181818182
# Шаг 115, доля выпавших орлов на данный момент 0.5217391304347826
# Шаг 120, доля выпавших орлов на данный момент 0.525
# Шаг 125, доля выпавших орлов на данный момент 0.512
# Шаг 130, доля выпавших орлов на данный момент 0.5076923076923077
# Шаг 135, доля выпавших орлов на данный момент 0.5037037037037037
# Шаг 140, доля выпавших орлов на данный момент 0.5
# Шаг 145, доля выпавших орлов на данный момент 0.4896551724137931
# Шаг 150, доля выпавших орлов на данный момент 0.49333333333333335
